# %%
# ---------------------------------------------------------
# EDA e Análise Estatística
# ---------------------------------------------------------
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("../data/processed/air_quality_clean.csv")
print(f"✅ Dataset carregado: {df.shape}")

# Estatísticas descritivas
print("\n📊 Estatísticas:")
print(df.describe().T)

# Top 10 cidades
plt.figure(figsize=(8,5))
sns.barplot(y=df['City'].value_counts().head(10).index,
            x=df['City'].value_counts().head(10).values,
            palette='crest')
plt.title("Top 10 cidades com mais registros")
plt.xlabel("Quantidade de registros")
plt.show()

# Distribuição de faixas de temperatura
sns.countplot(y='Temp_Bin', data=df, palette='coolwarm',
              order=df['Temp_Bin'].value_counts().index)
plt.title("Distribuição de Temperaturas")
plt.show()

# Correlação
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='RdBu_r', center=0)
plt.title("Matriz de Correlação")
plt.show()
# Out:
# ✅ Dataset carregado: (5203, 16)
#
# 📊 Estatísticas:
#                   count         mean        std      min          25%  \
# PM2.5            5203.0    77.707807  41.740855     5.02    41.820000
# PM10             5203.0   104.461545  55.275696    10.06    57.165000
# NO2              5203.0    51.762846  27.334706     5.01    27.635000
# SO2              5203.0    25.234484  14.157683     1.00    12.750000
# CO               5203.0     5.065612   2.844258     0.10     2.590000
# O3               5203.0   105.821386  55.116499    10.04    58.195000
# Temperature      5203.0    14.938837  14.423895   -10.00     2.345000
# Humidity         5203.0    55.217830  25.871135    10.01    32.945000
# Wind Speed       5203.0    10.195337   5.627537     0.51     5.240000
# Year             5203.0  2023.000000   0.000000  2023.00  2023.000000
# Month            5203.0     6.501057   3.433074     1.00     4.000000
# Pollution_Index  5203.0    61.675613  15.757978    15.61    50.309167
#
# ...
